# %% [markdown]
# <a href="https://colab.research.google.com/github/rghmf/Curso-Azure/blob/main/pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
nomes_f = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=f")
nomes_f
# Out:
#          nome  regiao      freq  rank sexo
# 0       MARIA       0  11694738     1    F
# 1         ANA       0   3079729     2    F
# 2   FRANCISCA       0    721637     3    F
# 3     ANTONIA       0    588783     4    F
# 4     ADRIANA       0    565621     5    F
# 5     JULIANA       0    562589     6    F
# 6      MARCIA       0    551855     7    F
# 7    FERNANDA       0    531607     8    F
# 8    PATRICIA       0    529446     9    F
# 9       ALINE       0    509869    10    F
# 10     SANDRA       0    479230    11    F
# 11     CAMILA       0    469851    12    F
# 12     AMANDA       0    464624    13    F
# 13      BRUNA       0    460770    14    F
# 14    JESSICA       0    456472    15    F
# 15    LETICIA       0    434056    16    F
# 16      JULIA       0    430067    17    F
# 17    LUCIANA       0    429769    18    F
# 18    VANESSA       0    417512    19    F
# 19    MARIANA       0    381778    20    F

# %%
nomes_m = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=m")

# %%
nomes_m
# Out:
#          nome  regiao     freq  rank sexo
# 0        JOSE       0  5732508     1    M
# 1        JOAO       0  2971935     2    M
# 2     ANTONIO       0  2567494     3    M
# 3   FRANCISCO       0  1765197     4    M
# 4      CARLOS       0  1483121     5    M
# 5       PAULO       0  1417907     6    M
# 6       PEDRO       0  1213557     7    M
# 7       LUCAS       0  1116818     8    M
# 8        LUIZ       0  1102927     9    M
# 9      MARCOS       0  1101126    10    M
# 10       LUIS       0   931530    11    M
# 11    GABRIEL       0   922744    12    M
# 12     RAFAEL       0   814709    13    M
# 13     DANIEL       0   706527    14    M
# 14    MARCELO       0   690098    15    M
# 15      BRUNO       0   663271    16    M
# 16    EDUARDO       0   628539    17    M
# 17     FELIPE       0   615924    18    M
# 18   RAIMUNDO       0   611174    19    M
# 19    RODRIGO       0   598825    20    M

# %%
nomes_f.sample(5)
# Out:
#        nome  regiao      freq  rank sexo
# 13    BRUNA       0    460770    14    F
# 5   JULIANA       0    562589     6    F
# 0     MARIA       0  11694738     1    F
# 10   SANDRA       0    479230    11    F
# 14  JESSICA       0    456472    15    F

# %%
print("Quantidade de nomes: " + str(len(nomes_f) + len(nomes_m)))
# Out:
# Quantidade de nomes: 40

# %%
frames = [nomes_f, nomes_m]

# %%
nomes = pd.concat(frames)['nome'].to_frame()
nomes.sample(5)
# Out:
#        nome
# 6     PEDRO
# 8      LUIZ
# 12   AMANDA
# 3   ANTONIA
# 5     PAULO

# %%
import numpy as np

# %%
total_alunos = len(nomes)

# %%
total_alunos
# Out:
# 40

# %%
nomes['id_aluno'] = np.random.permutation(total_alunos)

# %%
nomes.sample(5)
# Out:
#        nome  id_aluno
# 6     PEDRO         4
# 4    CARLOS        13
# 14  JESSICA         5
# 17   FELIPE        25
# 10     LUIS         9

# %%
dominios = ['@dominiodoemail.com.br', '@servicodoemail.com']
nomes['dominio'] = np.random.choice(dominios, total_alunos)

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno                 dominio
# 4     ADRIANA         1  @dominiodoemail.com.br
# 15    LETICIA        11  @dominiodoemail.com.br
# 2     ANTONIO        22  @dominiodoemail.com.br
# 5       PAULO        12     @servicodoemail.com
# 2   FRANCISCA        33  @dominiodoemail.com.br

# %%
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()

# %%
nomes.sample(5)
# Out:
#        nome  id_aluno                 dominio                        email
# 13    BRUNA        14  @dominiodoemail.com.br  bruna@dominiodoemail.com.br
# 8      LUIZ        39     @servicodoemail.com      luiz@servicodoemail.com
# 11  GABRIEL         3     @servicodoemail.com   gabriel@servicodoemail.com
# 1       ANA         8  @dominiodoemail.com.br    ana@dominiodoemail.com.br
# 7     LUCAS        37     @servicodoemail.com     lucas@servicodoemail.com

# %%
# !pip3 install html5lib
# !pip3 install lxml

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/'

# %%
cursos = pd.read_html(url)

# %%
type(cursos)
# Out:
# list

# %%
cursos[0]
# Out:
#                           Nome do curso
# 0                 Lógica de programação
# 1                         Java para Web
# 2                           C# para Web
# 3                         Ruby on Rails
# 4                      Cursos de Python
# 5                         PHP com MySql
# 6                         .NET para web
# 7            Novas integrações com Java
# 8                          TDD com Java
# 9                   Código limpo com C#
# 10  Preparatório para certificação Java
# 11                      Hardware básico
# 12                Persistência com .NET
# 13                  Desenvolvendo jogos
# 14                     Análise de dados
# 15                   Estatística básica
# 16                  Internet das coisas
# 17                Programação funcional
# 18                Boas práticas em Java
# 19          Orientação objetos com Java

# %%
type(cursos)
# Out:
# list

# %%
cursos = cursos[0]

# %%
type(cursos)
# Out:
# pandas.core.frame.DataFrame

# %%
cursos.head()
# Out:
#            Nome do curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %%
cursos = cursos.rename(columns = {'Nome do curso' : 'nome_do_curso'})

# %%
cursos.head()
# Out:
#            nome_do_curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %%
cursos['id'] = cursos.index + 1

# %%
cursos.head()
# Out:
#            nome_do_curso  id
# 0  Lógica de programação   1
# 1          Java para Web   2
# 2            C# para Web   3
# 3          Ruby on Rails   4
# 4       Cursos de Python   5

# %%
cursos = cursos.set_index('id')

# %%
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %%
nomes['matriculas'] = np.random.exponential(size=total_alunos).astype(int)

# %%
nomes.matriculas.describe()
# Out:
# count    40.000000
# mean      0.600000
# std       0.841244
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       3.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(nomes.matriculas)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
nomes.matriculas.value_counts()
# Out:
# 0    24
# 1     9
# 2     6
# 3     1
# Name: matriculas, dtype: int64

# %%
nomes.sample()
# Out:
#        nome  id_aluno                 dominio                          email  \
# 15  LETICIA        11  @dominiodoemail.com.br  leticia@dominiodoemail.com.br
#
#     matriculas
# 15           1

# %%
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %%
nomes.head()
# Out:
#         nome  id_aluno                 dominio  \
# 0      MARIA         0     @servicodoemail.com
# 1        ANA         8  @dominiodoemail.com.br
# 2  FRANCISCA        33  @dominiodoemail.com.br
# 3    ANTONIA         6  @dominiodoemail.com.br
# 4    ADRIANA         1  @dominiodoemail.com.br
#
#                              email  matriculas
# 0         maria@servicodoemail.com           1
# 1        ana@dominiodoemail.com.br           0
# 2  francisca@dominiodoemail.com.br           2
# 3    antonia@dominiodoemail.com.br           0
# 4    adriana@dominiodoemail.com.br           1

# %%
todas_matriculas = []
x = np.random.rand(20)
prob = x / sum(x)

# %%
for index, row in nomes.iterrows():
  id = row.id_aluno
  matriculas = row.matriculas
  for i in range(matriculas):
    mat = [id, np.random.choice(cursos.index, p = prob)]
    todas_matriculas.append(mat)

# %%
nomes.sample()
# Out:
#     nome  id_aluno                 dominio                       email  \
# 10  LUIS         9  @dominiodoemail.com.br  luis@dominiodoemail.com.br
#
#     matriculas
# 10           2

# %%
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python
